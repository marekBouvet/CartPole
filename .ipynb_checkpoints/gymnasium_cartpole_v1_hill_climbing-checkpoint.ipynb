# %% [markdown]
# # Hill Climbing (with adaptive noise scaling, without tensors)
# # CartPole-v1
#
# ---
#
#    In this notebook, we train the Hill Climbing Agent with
# **adaptive noise scaling** with OpenAI Gym's Cartpole environment.

# %% [markdown]
# ### Policy-Based Method
#
# In **policy-based methods**, instead of learning a **value function** that tells us what is
# the expected sum of rewards given a state and an action, we learn directly the **policy function**
# that maps state to action (select actions without using a value function).

# %% [markdown]
# ### 1. Import the Necessary Packages

# %%
import gymnasium as gym
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
#%matplotlib inline
import time

# %% [markdown]
# ### 2. Define the Policy

# %%
env = gym.make('CartPole-v1', render_mode="human")
print('observation space:', env.observation_space)
print('action space:', env.action_space)
threshold = env.spec.reward_threshold
print('threshold: ', threshold)

class Policy():
    def __init__(self, s_size=4, a_size=2):
        self.w = 1e-4*np.random.rand(s_size, a_size)  # weights for simple linear policy: state_space x action_space
        
    def forward(self, state):
        x = np.dot(state, self.w)
        return np.exp(x)/sum(np.exp(x))
    
    def act(self, state):
        if isinstance(state, tuple):
            state = state[0]
        probs = self.forward(state)
        #action = np.random.choice(2, p=probs) # option 1: stochastic policy
        action = np.argmax(probs)              # option 2: deterministic policy
        return action
# Out:
# observation space: Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)
# action space: Discrete(2)
# threshold:  475.0

# %% [markdown]
# ### 3. Train the Agent with Stochastic Policy Search

# %%
# env.seed(0) deprecated, use env.reset(seed=0)
np.random.seed(0)

policy = Policy()

def hill_climbing(n_episodes=1000, gamma=0.99, print_every=100, noise_scale=1e-2):
    """Implementation of hill climbing with adaptive noise scaling.
        
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        gamma (float): discount rate
        print_every (int): how often to print average score (over last 100 episodes)
        noise_scale (float): standard deviation of additive noise
    """
    scores_deque = deque(maxlen=100)
    scores = []
    arr_noise = []
    best_Gt = -np.Inf
    best_w = policy.w
    for i_episode in range(1, n_episodes+1):
        rewards = []
        state = env.reset()
        timesteps = 0 ## is the same as len(rewards)
        
        while True:
            action = policy.act(state)
            state, reward, done, truncated, info = env.step(action)            
            rewards.append(reward)
            timesteps += 1  
            if done or truncated:
                break 
                
        total_reward = sum(rewards)        
        scores_deque.append(total_reward)
        scores.append(total_reward)

        discounts = [gamma**i for i in range(len(rewards)+1)]
        ## This is the 'cumulative discounted reward' or TD-target G_t
        Gt = sum([a*b for a,b in zip(discounts, rewards)])
        
        if Gt >= best_Gt: # found better weights
            ## if Gt > best_R ==> decrease the noise: noise = noise/2  (till 0.001)
            best_Gt = Gt
            best_w = policy.w
            noise_scale = max(1e-3, noise_scale / 2)
            print('Ep.: {:3d} , timesteps: {:3d}, noise_scale (Gt >= best(Gt)): {:.4f}, Gt {:.4f}, \tAvg.Score:  {:.3f}'\
                  .format(i_episode, timesteps, noise_scale, Gt, np.mean(scores_deque)))
            policy.w += noise_scale * np.random.rand(*policy.w.shape) 
        else: # did not find better weights
            ## if Gt < best_R ==> increase the noise: noise = 2*noise (till 2)
            noise_scale = min(2, noise_scale * 2)
            print('Ep.: {:3d} , timesteps: {:3d}, noise_scale (Gt < best(Gt)): {:.4f}, Gt {:.4f}, \tAvg.Score:  {:.3f}'\
                  .format(i_episode, timesteps, noise_scale, Gt, np.mean(scores_deque)))
            policy.w = best_w + noise_scale * np.random.rand(*policy.w.shape)
            
        arr_noise.append(noise_scale)   

        if np.mean(scores_deque)>=threshold:
            print('Environment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))
            policy.w = best_w
            break
    
    return scores, arr_noise
            
scores, arr_noise = hill_climbing()
# Out:
# Ep.:   1 , timesteps: 119, noise_scale (Gt >= best(Gt)): 0.0050, Gt 69.7596, 	Avg.Score:  119.000
# Ep.:   2 , timesteps:  39, noise_scale (Gt < best(Gt)): 0.0100, Gt 32.4271, 	Avg.Score:  79.000
# Ep.:   3 , timesteps:  67, noise_scale (Gt < best(Gt)): 0.0200, Gt 49.0014, 	Avg.Score:  75.000
# Ep.:   4 , timesteps:  11, noise_scale (Gt < best(Gt)): 0.0400, Gt 10.4662, 	Avg.Score:  59.000
# Ep.:   5 , timesteps:  11, noise_scale (Gt < best(Gt)): 0.0800, Gt 10.4662, 	Avg.Score:  49.400
# Ep.:   6 , timesteps:  20, noise_scale (Gt < best(Gt)): 0.1600, Gt 18.2093, 	Avg.Score:  44.500
# Ep.:   7 , timesteps:   8, noise_scale (Gt < best(Gt)): 0.3200, Gt 7.7255, 	Avg.Score:  39.286
# Ep.:   8 , timesteps:   8, noise_scale (Gt < best(Gt)): 0.6400, Gt 7.7255, 	Avg.Score:  35.375
# Ep.:   9 , timesteps:   8, noise_scale (Gt < best(Gt)): 1.2800, Gt 7.7255, 	Avg.Score:  32.333
# Ep.:  10 , timesteps:  19, noise_scale (Gt < best(Gt)): 2.0000, Gt 17.3831, 	Avg.Score:  31.000
# Ep.:  11 , timesteps:   8, noise_scale (Gt < best(Gt)): 2.0000, Gt 7.7255, 	Avg.Score:  28.909
# Ep.:  12 , timesteps:  11, noise_scale (Gt < best(Gt)): 2.0000, Gt 10.4662, 	Avg.Score:  27.417
# Ep.:  13 , timesteps:  28, noise_scale (Gt < best(Gt)): 2.0000, Gt 24.5281, 	Avg.Score:  27.462
# Ep.:  14 , timesteps: 148, noise_scale (Gt >= best(Gt)): 1.0000, Gt 77.4052, 	Avg.Score:  36.071
# Ep.:  15 , timesteps:  70, noise_scale (Gt < best(Gt)): 2.0000, Gt 50.5161, 	Avg.Score:  38.333
# Ep.:  16 , timesteps:  52, noise_scale (Gt < best(Gt)): 2.0000, Gt 40.7034, 	Avg.Score:  39.188
# Ep.:  17 , timesteps:  49, noise_scale (Gt < best(Gt)): 2.0000, Gt 38.8883, 	Avg.Score:  39.765
# Ep.:  18 , timesteps:  52, noise_scale (Gt < best(Gt)): 2.0000, Gt 40.7034, 	Avg.Score:  40.444
# Ep.:  19 , timesteps: 500, noise_scale (Gt >= best(Gt)): 1.0000, Gt 99.3430, 	Avg.Score:  64.632
# Ep.:  20 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.5000, Gt 99.3430, 	Avg.Score:  86.400
# Ep.:  21 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.2500, Gt 99.3430, 	Avg.Score:  106.095
# Ep.:  22 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.1250, Gt 99.3430, 	Avg.Score:  124.000
# Ep.:  23 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0625, Gt 99.3430, 	Avg.Score:  140.348
# Ep.:  24 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0312, Gt 99.3430, 	Avg.Score:  155.333
# Ep.:  25 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0156, Gt 99.3430, 	Avg.Score:  169.120
# Ep.:  26 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0078, Gt 99.3430, 	Avg.Score:  181.846
# Ep.:  27 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0039, Gt 99.3430, 	Avg.Score:  193.630
# Ep.:  28 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0020, Gt 99.3430, 	Avg.Score:  204.571
# Ep.:  29 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  214.759
# Ep.:  30 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  224.267
# Ep.:  31 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  233.161
# Ep.:  32 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  241.500
# Ep.:  33 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  249.333
# Ep.:  34 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  256.706
# Ep.:  35 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  263.657
# Ep.:  36 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  270.222
# Ep.:  37 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  276.432
# Ep.:  38 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  282.316
# Ep.:  39 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  287.897
# Ep.:  40 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  293.200
# Ep.:  41 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  298.244
# Ep.:  42 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  303.048
# Ep.:  43 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  307.628
# Ep.:  44 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  312.000
# Ep.:  45 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  316.178
# Ep.:  46 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  320.174
# Ep.:  47 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  324.000
# Ep.:  48 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  327.667
# Ep.:  49 , timesteps: 500, noise_scale (Gt >= best(Gt)): 0.0010, Gt 99.3430, 	Avg.Score:  331.184

# %% [markdown]
# ### 4. Plot the Scores

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score, gamma=0.99')
plt.xlabel('Episode #')
plt.show()

# %%
ax2 = fig.add_subplot(121)
plt.plot(np.arange(1, len(arr_noise)+1), arr_noise)
plt.ylabel('Noise Scale, gamma=0.99')
plt.xlabel('Episode #')
plt.show()

# %% [markdown]
# ### 5. Watch a Smart Agent!
#
# Each step of the Smart Agent animation includes the cl of the following _action_, _state_ and _reward_.
# This also includes a slight _delay_ (0.1 sec) for better observation of the animation, and  further rendering.

# %%
t1 = time.time()

state = env.reset()
timesteps = 0
while True:
    action = policy.act(state)
    env.render()
    time.sleep(0.05)
    timesteps += 1
    state, reward, done, truncated, info = env.step(action)
    if done or truncated:
        break 

print('timesteps: ', timesteps)
delta = time.time() - t1
print('time : ', delta)
env.close()
# Out:
# timesteps:  500
# time :  36.943196058273315
